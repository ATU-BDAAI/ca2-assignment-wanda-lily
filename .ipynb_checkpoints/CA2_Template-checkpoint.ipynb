# %% [markdown]
#  *Artificial Intelligence for Vision & NLP* &nbsp; | &nbsp;  *ATU Donegal - Postgrad Diploma in Big Data Analytics & Artificial Intelligence*
#
# # Student Submisison
# Name           : Tope Lawal              <br>
# Student Number : L00196406        <br>
# Due Date       : 12 May, 2026            <br>
# Assignment     : CA2             <br>
# Module         : AI for Vision and NLP    <br>
# Course         : Postgraduate Diploma in Big Data Analytics and AI

# %% [markdown]
# ## NLP and Vision Pipeline : High Level
# An image of your working pipeline at high level can be inserted here

# %% [markdown]
# # Initialisation
# Perform pip installs(or use a requirements.txt) <br>
# perform imports

# %%
# ── Standard Library ──
import os
import re
import json
from pathlib import Path

# ── Image Processing ──
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# ── OCR ──
import pytesseract
from pytesseract import Output
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# ── NLP ──
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# ── Data Handling ──
import pandas as pd

# ── Display ──
from IPython.display import display, HTML

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Setting global params for matplotlib
plt.rcParams['figure.figsize'] = (20, 20)

print("Good to go! All libraries loaded successfully.")
print(f"OpenCV version: {cv2.__version__}")
print(f"spaCy version: {spacy.__version__}")
# Out:
# Good to go! All libraries loaded successfully.
# OpenCV version: 4.13.0
# spaCy version: 3.8.14

# %% [markdown]
# # Support Functions

# %%
# image path
IMAGE_PATH = r"C:\Users\Tope\Desktop\NLP-CA2\screenshot-test1.png"   

# load image
def load_image(path):
    """Load image using OpenCV and convert to RGB for display."""
    img_bgr = cv2.imread(path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found at: {path}")
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_bgr, img_rgb

# display image
def show_image(img_rgb, title="Document", figsize=(12, 8)):
    """Display an image with a title using matplotlib."""
    plt.figure(figsize=figsize)
    plt.imshow(img_rgb)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# load and display
img_bgr, img_rgb = load_image(IMAGE_PATH)
show_image(img_rgb, title="Original Document Image")
print(f"Image shape: {img_rgb.shape}  (Height x Width x Channels)")
# Out:
# Image shape: (593, 1257, 3)  (Height x Width x Channels)

# %% [markdown]
# # Image Preprocessing

# %%
def preprocess_image(img_bgr):
    """
    Full image preprocessing pipeline for document OCR preparation.
    
    Steps:
    1. Grayscale conversion
    2. Gaussian blur (noise reduction)
    3. Adaptive thresholding (binarisation)
    4. Morphological operations (remove small noise)
    
    Returns: preprocessed binary image, and intermediate stages for display.
    """
    stages = {}
    
    # Step 1: Convert to grayscale
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    stages['1_grayscale'] = gray
    
    # Step 2: Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    stages['2_blurred'] = blurred
    
    # Step 3: Adaptive thresholding — handles variable lighting across page
    # ADAPTIVE_THRESH_GAUSSIAN_C: weights neighbours by Gaussian window
    thresh = cv2.adaptiveThreshold(
        blurred, 255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY,
        blockSize=11,
        C=2
    )
    stages['3_threshold'] = thresh
    
    # Step 4: Morphological opening to remove small noise dots
    kernel = np.ones((1, 1), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
    stages['4_cleaned'] = cleaned
    
    return cleaned, stages


def show_preprocessing_stages(stages):
    """Display all preprocessing stages side by side."""
    fig, axes = plt.subplots(1, len(stages), figsize=(16, 4))
    titles = {
        '1_grayscale': 'Step 1:\nGrayscale',
        '2_blurred': 'Step 2:\nGaussian Blur',
        '3_threshold': 'Step 3:\nAdaptive Threshold',
        '4_cleaned': 'Step 4:\nMorphological Clean'
    }
    for ax, (key, img) in zip(axes, stages.items()):
        ax.imshow(img, cmap='gray')
        ax.set_title(titles.get(key, key), fontsize=10)
        ax.axis('off')
    plt.suptitle('Image Preprocessing Pipeline', fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()


# run preprocessing
preprocessed, stages = preprocess_image(img_bgr)
show_preprocessing_stages(stages)
print("Preprocessing complete.")
# Out:
# Preprocessing complete.

# %% [markdown]
# # OCR Text Extraction

# %% [markdown]
# started with --oem 3 default and --psm6 (assume block of text),
# but **config='--oem 1 --psm 3** showed better result based on test1.png

# %%
def extract_text(preprocessed_img, original_img_rgb, config='--oem 1 --psm 3'):
    """
    Extract text from preprocessed image using Tesseract OCR.
    
    Args:
        preprocessed_img: Binary preprocessed image
        original_img_rgb: Original image for visualisation
        config: Tesseract config string
            --oem 1: Neural network-based OCR (more accurate but slower).
            --psm 3: Fully automatic page segmentation
            
    
    Returns:
        raw_text: Full extracted text string
        word_data: DataFrame with word-level bounding boxes and confidence
    """
    # full text extraction
    raw_text = pytesseract.image_to_string(preprocessed_img, config=config)
    
    # detailed word-level data
    word_data = pytesseract.image_to_data(
        preprocessed_img, 
        config=config,
        output_type=Output.DATAFRAME
    )
    # filter out empty/low-confidence words
    word_data = word_data[
        (word_data['conf'] > 30) & 
        (word_data['text'].str.strip() != '')
    ].reset_index(drop=True)
    
    return raw_text, word_data


def visualise_ocr_boxes(img_rgb, word_data):
    """Draw bounding boxes around detected words, coloured by confidence."""
    img_copy = img_rgb.copy()
    
    for _, row in word_data.iterrows():
        x, y, w, h = int(row['left']), int(row['top']), int(row['width']), int(row['height'])
        conf = float(row['conf'])
        
        # colour by confidence: green=high, orange=medium, red=low
        if conf >= 80:
            colour = (0, 200, 0)
        elif conf >= 50:
            colour = (255, 165, 0)
        else:
            colour = (200, 0, 0)
        
        cv2.rectangle(img_copy, (x, y), (x + w, y + h), colour, 1)
    
    plt.figure(figsize=(14, 9))
    plt.imshow(img_copy)
    
    # legend
    patches = [
        mpatches.Patch(color='green', label='High confidence (≥80%)'),
        mpatches.Patch(color='orange', label='Medium confidence (50–79%)'),
        mpatches.Patch(color='red', label='Low confidence (<50%)')
    ]
    plt.legend(handles=patches, loc='upper right', fontsize=9)
    plt.title('OCR Word Detection — Confidence Map', fontsize=13, fontweight='bold')
    plt.axis('off')
    plt.tight_layout()
    plt.show()


# run OCR
raw_text, word_data = extract_text(preprocessed, img_rgb)

print("-" * 150)
print("EXTRACTED TEXT (RAW)")
print("-" * 150)
print(raw_text)
print(f"\nTotal words detected: {len(word_data)}")
print(f"Average OCR confidence: {word_data['conf'].mean():.1f}%")

visualise_ocr_boxes(img_rgb, word_data)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# EXTRACTED TEXT (RAW)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# You are a senior product marketing manager at Apple and you have just unveiled the latest
#
# ‘Apple product in collaboration with esta, the Apple Car, and received 12,000 pre-orders,
# which is 200% higher than target
#
# Write an email to your bossyTim Cookie, sharing this positive news.
# ° ‘The email should include a tl;dr (too long, didn’t read) section; project background (why this|
#
# ° product came into existence), business results section (quantifiable business metrics),and
#
# end with a section dedicated to thanking the product and engineering teams.
# ° Use clear and concise language and write in a confident yet friendly tone.
#
# °
#
# I just launched anew product; the apple car, received 12,00 pre-orders: Please write an email
#
# ito my boss with this update
#
#
#
# Total words detected: 117
# Average OCR confidence: 88.2%

# %% [markdown]
# # Text Preprocessing & NLP Analysis

# %% [markdown]
# Basically, Cleaning, Tokenisation, Stop word removal,Lemmatisation, Named Entity Recognition (NER)

# %%
def clean_ocr_text(ocr_text):
    """
    Regex clean raw OCR output by removing common OCR artefacts
    """
    # remove non-ASCII characters
    text = raw_text.encode('ascii', 'ignore').decode()
    # collapse multiple whitespace
    text = re.sub(r'\s+', ' ', text)
    # remove lines with only special characters (OCR noise)
    lines = [line.strip() for line in text.split('\n') 
             if len(re.sub(r'[^a-zA-Z0-9]', '', line)) > 2]
    return '\n'.join(lines)


def preprocess_text(text):
    """
    NLP preprocessing pipeline using spaCy.
    
    Returns a dict with:
    - tokens: all tokens
    - clean_tokens: tokens after stopword & punctuation removal
    - lemmas: lemmatised clean tokens
    - sentences: detected sentences
    - doc: spaCy Doc object
    """
    doc = nlp(text)
    
    tokens = [token.text for token in doc]

    # all tokens not stop or punctuation
    clean_tokens = [
        token.text.lower() for token in doc
        if not token.is_stop          # remove stop words
        and not token.is_punct        # remove punctuation
        and not token.is_space        # remove whitespace tokens
        and len(token.text) > 2       # remove very short tokens
    ]

    # base forms using spacy
    lemmas = [
        token.lemma_.lower() for token in doc
        if not token.is_stop
        and not token.is_punct
        and not token.is_space
        and len(token.text) > 2
    ]
    
    sentences = [sent.text.strip() for sent in doc.sents]
    
    return {
        'tokens': tokens,
        'clean_tokens': clean_tokens,
        'lemmas': lemmas,
        'sentences': sentences,
        'doc': doc
    }


# run text preprocessing
cleaned_text = clean_ocr_text(raw_text)
nlp_results = preprocess_text(cleaned_text)

print(f"Original token count:     {len(nlp_results['tokens'])}")
print(f"After stop word removal:  {len(nlp_results['clean_tokens'])}")
print(f"Unique lemmas:            {len(set(nlp_results['lemmas']))}")
print(f"Sentences detected:       {len(nlp_results['sentences'])}")
print(f"\nSample lemmas: {nlp_results['lemmas'][:15]}")
# Out:
# Original token count:     141
# After stop word removal:  74
# Unique lemmas:            56
# Sentences detected:       4
#
# Sample lemmas: ['senior', 'product', 'marketing', 'manager', 'apple', 'unveil', 'late', 'apple', 'product', 'collaboration', 'esta', 'apple', 'car', 'receive', '12,000']

# %%
#  Named Entity Recognition (NER)
def extract_entities(doc):
    """
    Extract named entities using spaCy's NER model.
    Groups entities by type.
    """
    entities = {}
    for ent in doc.ents:
        label = ent.label_
        if label not in entities:
            entities[label] = []
        if ent.text not in entities[label]:
            entities[label].append(ent.text)
    return entities


def visualise_ner(doc):
    """Display NER annotations using spaCy displacy."""
    from spacy import displacy
    html = displacy.render(doc, style='ent', page=False)
    display(HTML(html))


entities = extract_entities(nlp_results['doc'])

print("-" * 150)
print("NAMED ENTITY RECOGNITION RESULTS")
print("-" * 150)
for entity_type, values in entities.items():
    print(f"  {entity_type:15s}: {', '.join(values[:5])}")
print("\n")
print("-" * 150)
print("NER VISUALISAION")
print("-" * 150)
visualise_ner(nlp_results['doc'])
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# NAMED ENTITY RECOGNITION RESULTS
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#   ORG            : Apple
#   PRODUCT        : the Apple Car
#   CARDINAL       : 12,000
#   PERCENT        : 200%
#   PERSON         : Cookie
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# NER VISUALISAION
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">You are a senior product marketing manager at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and you have just unveiled the latest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  product in collaboration with esta,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Apple Car
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , and received
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pre-orders, which is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  higher than target Write an email to your bossyTim
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cookie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , sharing this positive news. The email should include a tl;dr (too long, didnt read) section; project background (why this| product came into existence), business results section (quantifiable business metrics),and end with a section dedicated to thanking the product and engineering teams. Use clear and concise language and write in a confident yet friendly tone. I just launched anew product; the apple car, received 12,00 pre-orders: Please write an email ito my boss with this update</div></span>

# %% [markdown]
# # Vision

# %% [markdown]
# ## Sub Heading 1

# %%
# code here...

# %% [markdown]
# # Multi-modal

# %% [markdown]
# ## Sub Heading 1

# %%
# code here

# %% [markdown]
# # Final Output

# %%
# code
